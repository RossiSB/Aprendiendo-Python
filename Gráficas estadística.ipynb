# %% [markdown]
# # Ejercicios Gráficos

# %% [markdown]
# **3.5.1**

# %%
import matplotlib.pyplot as plt
import numpy as np
x = (5,7,6,2,8,9,3,4,1,9,5,4,6,4,8,7,6,2,8,9)
y = (7,8,5,6,8,3,2,9,9,6,1,5,7,3,5,4,5,9,7,6)

plt.scatter(x,y)
plt.xlabel("x")
plt.ylabel("y")
plt.show()
print(np.corrcoef(x,y))

# %% [markdown]
# **3.5.2**

# %%
import matplotlib.pyplot as plt
import numpy as np
lengua = (5,7,6,2,8,9,3,4,1,9,5,4,6,4,8,7,6,2,8,9)
ingles = (7,9,7,5,9,9,5,6,3,9,7,6,8,6,9,8,8,4,9,9)
plt.scatter(lengua,ingles)
plt.xlabel("lengua")
plt.ylabel("ingles")
plt.show()
print(np.corrcoef(lengua,ingles))
# Out:
# [[1.         0.96878201]
#  [0.96878201 1.        ]]

# %% [markdown]
# **3.5.3 Dadas la siguiente lista con las edades de diferentes personas que trabajan en el sector TIC, realiza un histograma que muestre la frecuencia de cada grupo de edad.**

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns


edades = [25, 36, 25, 20, 35, 24, 42, 44, 51,
          32, 36, 36, 25, 29, 28, 25, 36, 37,
          29, 44, 42, 41, 40, 40, 42, 51, 25,
          26, 28, 27, 32, 31, 30, 31, 39, 36,
          36, 32, 23, 26, 24, 27, 46, 46, 48]



plt.hist(edades, bins= 10, color= "orange")
plt.title("Histograma de edades")

plt.show()

# %%
sns.displot(edades)
plt.show()

# %% [markdown]
# **3.5.4**

# %%
import matplotlib.pyplot as plt
datos = edades = [25, 36, 25, 20, 35, 24, 42, 44, 51,
          32, 36, 36, 25, 29, 28, 25, 36, 37,
          29, 44, 42, 41, 40, 40, 42, 51, 25,
          26, 28, 27, 32, 31, 30, 31, 39, 36,
          36, 32, 23, 26, 24, 27, 46, 46, 48]

plt.boxplot(datos,vert=False)
plt.title("Edades")
plt.show()

# %% [markdown]
# **3.5.5**

# %%
import matplotlib.pyplot as plt
ventas = []
meses = ["Enero", "Febrero", "Marzo", "Abril",
         "Mayo", "Junio","Julio", "Agosto", 
         "Septiembre", "Octubre", "Noviembre", "Diciembre"]
for mes in meses:
    venta = float(input(f"Ingrese las ventas de {mes}: "))
    ventas.append(venta)

# Creando el gráfico de barras
plt.bar(meses, ventas)
plt.title("Ventas mensuales")
plt.xlabel("Meses")
plt.ylabel("Ventas")

plt.xticks(rotation=45, color="purple")


plt.show()
# Out:
# Ingrese las ventas de Enero: 465
# Ingrese las ventas de Febrero: 854
# Ingrese las ventas de Marzo: 964
# Ingrese las ventas de Abril: 225
# Ingrese las ventas de Mayo: 658
# Ingrese las ventas de Junio: 745
# Ingrese las ventas de Julio: 856
# Ingrese las ventas de Agosto: 256
# Ingrese las ventas de Septiembre: 364
# Ingrese las ventas de Octubre: 698
# Ingrese las ventas de Noviembre: 157
# Ingrese las ventas de Diciembre: 265

# %% [markdown]
# **3.5.6 Dado el archivo CSV apellidos_mas_frecuentes_pais_Argentina.csv, compartido por el tutor en este foro, crea un dataframe con los datos contenidos en él y genera un gráfico de caja con los datos que hay en la variable porcentaje_de_poblacion_portadora. ¿Hay algún dato fuera de rango?**

# %%
import pandas as pd
import matplotlib.pyplot as plt


df = pd.read_csv((r"C:\Users\Hp\Downloads\apellidos_mas_frecuentes_pais_Argentina.csv"), sep=",")
df
plt.boxplot(df["porcentaje_de_poblacion_portadora"])
plt.title("Porcentaje de población portadora de apellido en Argentina")
plt.ylabel("Porcentaje")
plt.show()

# %% [markdown]
# **3.5.7**

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(['A', 'B', 'C', 'D', 'E'])
y = np.array([10, 8, 6, 4, 2])

plt.bar(x, y)
plt.xticks(rotation=0)
plt.show()
