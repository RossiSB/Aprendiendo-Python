# %% [markdown]
# **Ejercicio 3.6.1.**

# %%
import pandas as pd
datos = pd.read_csv(r"C:\Users\Hp\Downloads\Esculturas_Parque_Arqueolgicos_Colombia.csv", sep =",")
df= pd.DataFrame(datos)
df.head()
# Out:
#   Parque Arqueologico Elemento arqueológico  \
# 0         San Agustín             escultura
# 1         San Agustín             escultura
# 2         San Agustín             escultura
# 3         San Agustín             escultura
# 4         San Agustín             escultura
#
#                     Nombre elemento arqueológico Código ICANH  \
# 0                    Figura masculina sin rostro     No.  380
# 1  Figura masculina con una cara sobre el cuerpo       No. 24
# 2                       Figura con una serpiente       No. 40
# 3                              Guardián de tumba       No. 65
# 4                              Guardián de tumba       No. 70
#
#                                          Descripción  \
# 0  Personaje sin rostro. Lleva tocado en la cabez...
# 1  Figura humana que tiene  cubierta la cabeza co...
# 2  La cabeza es excesivamente grande, el cuerpo p...
# 3  Figura de rastros antropomorfos, ojos ovalados...
# ...

# %% [markdown]
#  **Ejercicio 3.6.2 De los datos del registro cuyo índice es 105. ¿Cuál es el nombre del elemento buscado?**

# %%
df.iloc[[105],[2]]

# %%
df.loc[[105],["Nombre elemento arqueológico"]]

# %% [markdown]
#  **Ejercicio 3.6.3 Muestra el nombre y la ubicación de los registros cuyos índices son 24, 36, 125 y 182. ¿Alguno de los elementos está en la misma ubicación?**

# %%
filtro = df.loc[[24,36,125,182],["Nombre elemento arqueológico","Ubicación actual dentro del parque"]]
filtrado = pd.DataFrame(filtro)

filtrado

# %%
indices_bosque = filtrado.loc[filtrado["Ubicación actual dentro del parque"] == "Bosque de las estatuas"]

indices_bosque

# %%
duplicados = filtrado.duplicated(subset=["Ubicación actual dentro del parque"], keep=False) # subset  indica que sólo se deben considerar las filas que tienen la misma ubicación.

if any(duplicados):
    d = filtrado[duplicados]
else:
    print("No hay elementos en la misma ubicación")
d

# %% [markdown]
# **Ejercicio 3.6.4 Muestra el código ICANH de los registros con índices entre el 100 y 110.**

# %%
df.loc[100:110,["Código ICANH"]]

# %%
df.loc[100:110,"Código ICANH"]
# Out:
# 100     No 133
# 101     No.138
# 102    No 155A
# 103     No.168
# 104     No.173
# 105     No.179
# 106    No. 483
# 107     No.213
# 108     No.234
# 109     No.369
# 110      No.41
# Name: Código ICANH, dtype: object

# %% [markdown]
# **Ejercicio 3.6.5 Muestras los elementos impares**

# %%
df.iloc[lambda x: x.index % 2 != 0]

# %% [markdown]
#  **Ejercicio 3.6.6 Muestra la ubicación actual de los registros cuyo índice tenga como valores 10, 20, 30, 40 y 50.**

# %%
indices = [10, 20, 30, 40, 50]
df.loc[indices, ["Ubicación actual dentro del parque"]]

# %%
df.loc[10:50:10, ["Ubicación actual dentro del parque"]]

# %% [markdown]
# **Ejercicio 3.6.7 Crea un nuevo dataframe basado en el anterior, pero cuyo índice sea Elemento arqueológico.**

# %%
nuevo = df.set_index("Elemento arqueológico")
df2 = pd.DataFrame(nuevo)
df2
# Out:
#                       Parque Arqueologico  \
# Elemento arqueológico
# escultura                     San Agustín
# escultura                     San Agustín
# escultura                     San Agustín
# escultura                     San Agustín
# escultura                     San Agustín
# ...                                   ...
# Anillo de terraza          Ciudad Perdida
# Muro de terraza            Ciudad Perdida
# Muro de terraza            Ciudad Perdida
# Unidad Visual              Ciudad Perdida
# Unidad Visual              Ciudad Perdida
#
#                                         Nombre elemento arqueológico  \
# Elemento arqueológico
# escultura                                Figura masculina sin rostro
# escultura              Figura masculina con una cara sobre el cuerpo
# escultura                                   Figura con una serpiente
# escultura                                          Guardián de tumba
# ...

# %% [markdown]
# **3.6.8, muestra todos los elementos que tienen un índice disto a escultura**

# %%
df2.iloc[lambda x: x.index !="escultura"]
# Out:
#                       Parque Arqueologico  \
# Elemento arqueológico
# Sarcófago                     San Agustín
# laja                          San Agustín
# laja                          San Agustín
# laja                          San Agustín
# estela                        San Agustín
# ...                                   ...
# Anillo de terraza          Ciudad Perdida
# Muro de terraza            Ciudad Perdida
# Muro de terraza            Ciudad Perdida
# Unidad Visual              Ciudad Perdida
# Unidad Visual              Ciudad Perdida
#
#                                             Nombre elemento arqueológico  \
# Elemento arqueológico
# Sarcófago                                                      Sarcófago
# laja                            Laja con representación de figura humana
# laja                                        Laja con rostro antropomorfo
# laja                   Relieve de  una figura femenina  que enseña un...
# ...

# %% [markdown]
# **3.6.9,muestra todos los elementos cuyo índice es Sarcófago. ¿Cuántos elementos hay?**

# %%
c = df2.iloc[lambda x: x.index =="Sarcófago"]
c
# Out:
#                       Parque Arqueologico  \
# Elemento arqueológico
# Sarcófago                     San Agustín
# Sarcófago                     San Agustín
# Sarcófago              Alto de los Idolos
# Sarcófago              Alto de los Idolos
# Sarcófago              Alto de los Idolos
#
#                                      Nombre elemento arqueológico  \
# Elemento arqueológico
# Sarcófago                                               Sarcófago
# Sarcófago                                               Sarcófago
# Sarcófago                                               Sarcófago
# Sarcófago               Sarcófago monolítico con dos agarraderas.
# Sarcófago              Sarcófago monolítico con tapa y vertedera.
#
#                       Código ICANH  \
# Elemento arqueológico
# Sarcófago                      S-2
# Sarcófago                      S-1
# Sarcófago                      S-3
# Sarcófago                      S-4
# Sarcófago                      S-5
#
# ...

# %%
print(f"Hay {len(c)} elementos con índice sarcófago en la nueva tabla.")
# Out:
# Hay 5 elementos con índice sarcófago en la nueva tabla.

# %% [markdown]
# **3.6.10, Convierte el resultado del ejercicio anterior en un nuevo dataframe, reinicia su índice y muestra el Parque Arqueologico de los 3 primeros elementos.**

# %%
nuevodf= pd.DataFrame(c)
nuevodf
# Out:
#                       Parque Arqueologico  \
# Elemento arqueológico
# Sarcófago                     San Agustín
# Sarcófago                     San Agustín
# Sarcófago              Alto de los Idolos
# Sarcófago              Alto de los Idolos
# Sarcófago              Alto de los Idolos
#
#                                      Nombre elemento arqueológico  \
# Elemento arqueológico
# Sarcófago                                               Sarcófago
# Sarcófago                                               Sarcófago
# Sarcófago                                               Sarcófago
# Sarcófago               Sarcófago monolítico con dos agarraderas.
# Sarcófago              Sarcófago monolítico con tapa y vertedera.
#
#                       Código ICANH  \
# Elemento arqueológico
# Sarcófago                      S-2
# Sarcófago                      S-1
# Sarcófago                      S-3
# Sarcófago                      S-4
# Sarcófago                      S-5
#
# ...

# %%
df_res =nuevodf.reset_index()
df_res
# Out:
#   Elemento arqueológico Parque Arqueologico  \
# 0             Sarcófago         San Agustín
# 1             Sarcófago         San Agustín
# 2             Sarcófago  Alto de los Idolos
# 3             Sarcófago  Alto de los Idolos
# 4             Sarcófago  Alto de los Idolos
#
#                  Nombre elemento arqueológico Código ICANH  \
# 0                                   Sarcófago          S-2
# 1                                   Sarcófago          S-1
# 2                                   Sarcófago          S-3
# 3   Sarcófago monolítico con dos agarraderas.          S-4
# 4  Sarcófago monolítico con tapa y vertedera.          S-5
#
#                                          Descripción  \
# 0  Sarcófago monolítico profundo de paredes relat...
# 1  Sarcófago monolítico con vertedera en la parte...
# 2          Sarcófago monolítico con canal de desague
# 3  Sarcófago monolítico ancho, de paredes gruesas...
# 4  Sarcófago monolítico con vertedera y tapa sin ...
#
# ...

# %%
df_res.loc[0:2,["Parque Arqueologico"]]
# Out:
#   Parque Arqueologico
# 0         San Agustín
# 1         San Agustín
# 2  Alto de los Idolos
